# %%
from analysis import *
from plotting import *

# %%
fr = (0.7, 1)
gr = (0.9, 1)
dejmps = analyze_multiple_combos(dejmps_data, fidelity_range=fr, gate_fidelity_range=gr)
bbpssw = analyze_multiple_combos(bbpssw_data, fidelity_range=fr, gate_fidelity_range=gr)
epl_local = analyze_multiple_combos(epl_local_change_data, fidelity_range=fr, gate_fidelity_range=gr)

# %%
plot_fidelity_heatmap(dejmps, deltas=True, highlight_positive_deltas=True, cbar_range=(-0.25, 0.25), bins=11, scatter_overlay=True, title='DEJMPS fidelity deltas')
plot_fidelity_heatmap(bbpssw, deltas=True, highlight_positive_deltas=True, cbar_range=(-0.25, 0.25), bins=11, scatter_overlay=True, title='BBSPSSW fidelity deltas')
plot_fidelity_heatmap(epl_local, deltas=True, highlight_positive_deltas=True, cbar_range=(-0.25, 0.25), bins=11, scatter_overlay=True, title=r'EPL (with $X_B$) fidelity deltas')

plot_success_probability_heatmap(dejmps, cbar_range=(0.3, 1), bins=11, scatter_overlay=True, title='DEJMPS success probabilities')
plot_success_probability_heatmap(bbpssw, cbar_range=(0.3, 1), bins=11, scatter_overlay=True, title='BBPSSW success probabilities')
plot_success_probability_heatmap(epl_local, cbar_range=(0.3, 1), bins=11, scatter_overlay=True, title=r'EPL (with $X_B$) success probabilities')
