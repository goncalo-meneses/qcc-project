# %%
from analysis import *
from plotting import *

# %%
fr = (0.7, 1)
gr = (0.9, 1)
print_protocol_summary(dejmps_data, fidelity_range=fr, gate_fidelity_range=gr)
# Out:
# Summary for protocol
# --------------------------------------------------
# Fidelity: 0.7000, Gate Fidelity: 0.9000 -> Simulations: 100
# Fidelity: 0.7000, Gate Fidelity: 0.9100 -> Simulations: 100
# Fidelity: 0.7000, Gate Fidelity: 0.9200 -> Simulations: 100
# Fidelity: 0.7000, Gate Fidelity: 0.9300 -> Simulations: 100
# Fidelity: 0.7000, Gate Fidelity: 0.9400 -> Simulations: 100
# Fidelity: 0.7000, Gate Fidelity: 0.9500 -> Simulations: 100
# Fidelity: 0.7000, Gate Fidelity: 0.9600 -> Simulations: 100
# Fidelity: 0.7000, Gate Fidelity: 0.9700 -> Simulations: 100
# Fidelity: 0.7000, Gate Fidelity: 0.9800 -> Simulations: 100
# Fidelity: 0.7000, Gate Fidelity: 0.9900 -> Simulations: 200
# Fidelity: 0.7000, Gate Fidelity: 0.9905 -> Simulations: 100
# Fidelity: 0.7000, Gate Fidelity: 0.9910 -> Simulations: 100
# Fidelity: 0.7000, Gate Fidelity: 0.9915 -> Simulations: 100
# Fidelity: 0.7000, Gate Fidelity: 0.9920 -> Simulations: 100
# ...

# %%
fr = (0.725, 0.725)
gr = (0.9, 1)
dejmps = analyze_multiple_combos(dejmps_data, fidelity_range=fr, gate_fidelity_range=gr)
bbpssw = analyze_multiple_combos(bbpssw_data, fidelity_range=fr, gate_fidelity_range=gr)
epl = analyze_multiple_combos(epl_data, fidelity_range=fr, gate_fidelity_range=gr)
epl_local = analyze_multiple_combos(epl_local_change_data, fidelity_range=fr, gate_fidelity_range=gr)

results_list = [('DEJMPS', dejmps),                
                ('BBPSSW', bbpssw),
                (r'EPL with $X_B$', epl_local)]
plot_fidelity(results_list, title='Input fidelity 0.725', delta=False)
plot_fidelity(results_list, title='Input fidelity 0.725', delta=True)

# %%
fr = (0.7, 1)
gr = (0.9, 1)
dejmps = analyze_multiple_combos(dejmps_data, fidelity_range=fr, gate_fidelity_range=gr)
bbpssw = analyze_multiple_combos(bbpssw_data, fidelity_range=fr, gate_fidelity_range=gr)
epl = analyze_multiple_combos(epl_data, fidelity_range=fr, gate_fidelity_range=gr)
epl_local = analyze_multiple_combos(epl_local_change_data, fidelity_range=fr, gate_fidelity_range=gr)


plot_combo_heatmap(dejmps, cbar_range=(0.4, 1))
plot_combo_heatmap(bbpssw, cbar_range=(0.4, 1))
plot_combo_heatmap(epl_local, cbar_range=(0.4, 1))

plot_combo_heatmap(dejmps, deltas=True, highlight_positive_deltas=True, cbar_range=(-0.25, 0.25))
plot_combo_heatmap(bbpssw, deltas=True, highlight_positive_deltas=True, cbar_range=(-0.25, 0.25))
plot_combo_heatmap(epl_local, deltas=True, highlight_positive_deltas=True, cbar_range=(-0.25, 0.25))

# %%
plot_combo_heatmap(dejmps, cbar_range=(0.45, 1), bins=11)
plot_combo_heatmap(bbpssw, cbar_range=(0.45, 1), bins=11)
plot_combo_heatmap(epl_local, cbar_range=(0.45, 1), bins=11)

plot_combo_heatmap(dejmps, deltas=True, highlight_positive_deltas=True, cbar_range=(-0.25, 0.25), bins=11)
plot_combo_heatmap(bbpssw, deltas=True, highlight_positive_deltas=True, cbar_range=(-0.25, 0.25), bins=11)
plot_combo_heatmap(epl_local, deltas=True, highlight_positive_deltas=True, cbar_range=(-0.25, 0.25), bins=11)

# %%
plot_combo_scatter(dejmps, cbar_range=(0.4, 1))
plot_combo_scatter(bbpssw, cbar_range=(0.4, 1))
plot_combo_scatter(epl_local, cbar_range=(0.4, 1))

plot_combo_scatter(dejmps, deltas=True, cbar_range=(-0.25, 0.25))
plot_combo_scatter(bbpssw, deltas=True, cbar_range=(-0.25, 0.25))
plot_combo_scatter(epl_local, deltas=True, cbar_range=(-0.25, 0.25))

# %%
plot_combo_heatmap(dejmps, cbar_range=(0.4, 1))
plot_combo_heatmap(bbpssw, cbar_range=(0.4, 1))
plot_combo_heatmap(epl_local, cbar_range=(0.4, 1))

plot_combo_heatmap(dejmps, deltas=True, cbar_range=(-0.25, 0.25))
plot_combo_heatmap(bbpssw, deltas=True, cbar_range=(-0.25, 0.25))
plot_combo_heatmap(epl_local, deltas=True, cbar_range=(-0.25, 0.25))

# %%
# all data
dejmps = analyze_multiple_combos(dejmps_data)
bbpssw = analyze_multiple_combos(bbpssw_data)
epl_local = analyze_multiple_combos(epl_local_change_data)

# %%
plot_combo_scatter(dejmps, cbar_range=(0.4, 1))
plot_combo_scatter(bbpssw, cbar_range=(0.4, 1))
plot_combo_scatter(epl_local, cbar_range=(0.4, 1))

plot_combo_scatter(dejmps, deltas=True)
plot_combo_scatter(bbpssw, deltas=True)
plot_combo_scatter(epl_local, deltas=True)
