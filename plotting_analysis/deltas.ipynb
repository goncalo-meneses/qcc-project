# %%
from analysis import *
from plotting import *

# %% [markdown]
# Examples plotting both actual value of output fidelity and difference between input and output fidelities. No protocols perform well, so maybe there's an error in the simulation or analysis.

# %%
fr = (0.9, 0.9)
gr = (0.99, 1)
print_protocol_summary(dejmps_data, fidelity_range=fr, gate_fidelity_range=gr)
# Out:
# Summary for protocol
# --------------------------------------------------
# Fidelity: 0.9000, Gate Fidelity: 0.9900 -> Simulations: 600
# Fidelity: 0.9000, Gate Fidelity: 0.9990 -> Simulations: 500
# Fidelity: 0.9000, Gate Fidelity: 1.0000 -> Simulations: 500

# %%
fr = (0.9, 0.9)
gr = (0.99, 1)
dejmps = analyze_multiple_combos(dejmps_data, fidelity_range=fr, gate_fidelity_range=gr, n_bootstrap=1000, seed=42)
bbpssw = analyze_multiple_combos(bbpssw_data, fidelity_range=fr, gate_fidelity_range=gr, n_bootstrap=1000, seed=42)
epl = analyze_multiple_combos(epl_data, fidelity_range=fr, gate_fidelity_range=gr, n_bootstrap=1000, seed=42)
epl_local = analyze_multiple_combos(epl_local_change_data, fidelity_range=fr, gate_fidelity_range=gr, n_bootstrap=1000, seed=42)

results_list = [('DEJMPS', dejmps),                
                ('BBPSSW', bbpssw),
                (r'EPL with $X_B$', epl_local)]
plot_fidelity(results_list, title='Input fidelity 0.9', delta=False)
plot_fidelity(results_list, title='Input fidelity 0.9', delta=True)

# %%
fr = (0.7, 0.7)
gr = (0.99, 1)
print_protocol_summary(dejmps_data, fidelity_range=fr, gate_fidelity_range=gr)
# Out:
# Summary for protocol
# --------------------------------------------------
# Fidelity: 0.7000, Gate Fidelity: 0.9900 -> Simulations: 200
# Fidelity: 0.7000, Gate Fidelity: 0.9905 -> Simulations: 100
# Fidelity: 0.7000, Gate Fidelity: 0.9910 -> Simulations: 100
# Fidelity: 0.7000, Gate Fidelity: 0.9915 -> Simulations: 100
# Fidelity: 0.7000, Gate Fidelity: 0.9920 -> Simulations: 100
# Fidelity: 0.7000, Gate Fidelity: 0.9925 -> Simulations: 100
# Fidelity: 0.7000, Gate Fidelity: 0.9930 -> Simulations: 100
# Fidelity: 0.7000, Gate Fidelity: 0.9935 -> Simulations: 100
# Fidelity: 0.7000, Gate Fidelity: 0.9940 -> Simulations: 100
# Fidelity: 0.7000, Gate Fidelity: 0.9945 -> Simulations: 100
# Fidelity: 0.7000, Gate Fidelity: 0.9950 -> Simulations: 100
# Fidelity: 0.7000, Gate Fidelity: 0.9955 -> Simulations: 100
# Fidelity: 0.7000, Gate Fidelity: 0.9960 -> Simulations: 100
# Fidelity: 0.7000, Gate Fidelity: 0.9965 -> Simulations: 100
# Fidelity: 0.7000, Gate Fidelity: 0.9970 -> Simulations: 100
# Fidelity: 0.7000, Gate Fidelity: 0.9975 -> Simulations: 100
# Fidelity: 0.7000, Gate Fidelity: 0.9980 -> Simulations: 100
# Fidelity: 0.7000, Gate Fidelity: 0.9985 -> Simulations: 100
# Fidelity: 0.7000, Gate Fidelity: 0.9990 -> Simulations: 100
# Fidelity: 0.7000, Gate Fidelity: 0.9995 -> Simulations: 100
# Fidelity: 0.7000, Gate Fidelity: 1.0000 -> Simulations: 200

# %%
fr = (0.7, 0.7)
gr = (0.99, 1)
dejmps = analyze_multiple_combos(dejmps_data, fidelity_range=fr, gate_fidelity_range=gr, n_bootstrap=1000, seed=42)
bbpssw = analyze_multiple_combos(bbpssw_data, fidelity_range=fr, gate_fidelity_range=gr, n_bootstrap=1000, seed=42)
epl = analyze_multiple_combos(epl_data, fidelity_range=fr, gate_fidelity_range=gr, n_bootstrap=1000, seed=42)
epl_local = analyze_multiple_combos(epl_local_change_data, fidelity_range=fr, gate_fidelity_range=gr, n_bootstrap=1000, seed=42)

results_list = [('DEJMPS', dejmps),
                ('BBPSSW', bbpssw),
                (r'EPL with $X_B$', epl_local)]
plot_fidelity(results_list, title='Input fidelity 0.7', delta=False)
plot_fidelity(results_list, title='Input fidelity 0.7', delta=True)
plot_success_prob(results_list, title='Input fidelity 0.7')

# %%
fr = (0.45, 0.55)
gr = (1, 1)
print_protocol_summary(dejmps_data, fidelity_range=fr, gate_fidelity_range=gr)
# Out:
# Summary for protocol
# --------------------------------------------------
# Fidelity: 0.4500, Gate Fidelity: 1.0000 -> Simulations: 700
# Fidelity: 0.4600, Gate Fidelity: 1.0000 -> Simulations: 500
# Fidelity: 0.4700, Gate Fidelity: 1.0000 -> Simulations: 500
# Fidelity: 0.4750, Gate Fidelity: 1.0000 -> Simulations: 200
# Fidelity: 0.4800, Gate Fidelity: 1.0000 -> Simulations: 500
# Fidelity: 0.4900, Gate Fidelity: 1.0000 -> Simulations: 500
# Fidelity: 0.5000, Gate Fidelity: 1.0000 -> Simulations: 700
# Fidelity: 0.5100, Gate Fidelity: 1.0000 -> Simulations: 500
# Fidelity: 0.5200, Gate Fidelity: 1.0000 -> Simulations: 500
# Fidelity: 0.5250, Gate Fidelity: 1.0000 -> Simulations: 200
# Fidelity: 0.5300, Gate Fidelity: 1.0000 -> Simulations: 500
# Fidelity: 0.5400, Gate Fidelity: 1.0000 -> Simulations: 500
# Fidelity: 0.5500, Gate Fidelity: 1.0000 -> Simulations: 700

# %%
fr = (0.5, 1)
gr = (1, 1)
dejmps = analyze_multiple_combos(dejmps_data, fidelity_range=fr, gate_fidelity_range=gr, n_bootstrap=1000, seed=42)
bbpssw = analyze_multiple_combos(bbpssw_data, fidelity_range=fr, gate_fidelity_range=gr, n_bootstrap=1000, seed=42)
epl = analyze_multiple_combos(epl_data, fidelity_range=fr, gate_fidelity_range=gr, n_bootstrap=1000, seed=42)
epl_local = analyze_multiple_combos(epl_local_change_data, fidelity_range=fr, gate_fidelity_range=gr, n_bootstrap=1000, seed=42)

results_list = [('DEJMPS', dejmps),
                ('BBPSSW', bbpssw),
                (r'EPL with $X_B$', epl_local)]
plot_fidelity(results_list, title='Gate fidelity 1', delta=False, theoretical_f=True, fr=fr)
plot_fidelity(results_list, title='Gate fidelity 1', delta=True)
plot_success_prob(results_list, title='Gate fidelity 1', theoretical_p=True, fr=fr)

# %%
fr = (0.5, 1)
gr = (1, 1)
dejmps = analyze_multiple_combos(dejmps_data, fidelity_range=fr, gate_fidelity_range=gr, n_bootstrap=1000, seed=42)
bbpssw = analyze_multiple_combos(bbpssw_data, fidelity_range=fr, gate_fidelity_range=gr, n_bootstrap=1000, seed=42)
epl = analyze_multiple_combos(epl_data, fidelity_range=fr, gate_fidelity_range=gr, n_bootstrap=1000, seed=42)
epl_local = analyze_multiple_combos(epl_local_change_data, fidelity_range=fr, gate_fidelity_range=gr, n_bootstrap=1000, seed=42)

results_list = [('BBPSSW', bbpssw),]

plot_fidelity_vs_success(results_list, gate_fidelity=1.0, title="Gate fidelity 1", xlim=(0.45, 1.05))
# Out:
# (<Figure size 1000x600 with 1 Axes>,
#  <Axes: title={'center': 'Gate fidelity 1'}, xlabel='Success Probability', ylabel='Output Fidelity'>)

# %%
results_list = [('DEJMPS', dejmps),]

plot_fidelity_vs_success(results_list, gate_fidelity=0.9, title="Gate fidelity 1", show_theory=False)
# Out:
# No data found for protocol DEJMPS with gate fidelity 0.9
# /home/goncalomeneses/qcc-project/plotting_analysis/plotting.py:411: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(loc='best')
# (<Figure size 1000x600 with 1 Axes>,
#  <Axes: title={'center': 'Gate fidelity 1'}, xlabel='Success Probability', ylabel='Output Fidelity'>)
